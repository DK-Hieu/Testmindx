# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from io import StringIO
from sklearn.linear_model import LinearRegression
from pycaret.regression import *
print('Completed import lib')
# Out:
# Completed import lib

# %%
df = pd.read_csv('test1_pycaret.csv')
df.drop(columns='Unnamed: 0', inplace=True)
df
# Out:
#       emp_title  verified_income  loan_purpose  grade  sub_grade  loan_status  \
# 0          3298                1             1      3         13            1
# 1          4567                2             2      3         11            1
# 2           197                3             3      4         16            1
# 3          3081                2             2      1          3            1
# 4          3249                1             4      3         13            1
# ...         ...              ...           ...    ...        ...          ...
# 9995       4391                3             3      1          4            1
# 9996         88                1             2      4         18            1
# 9997       1807                1             2      5         22            1
# 9998       1772                3             3      1          1            1
# 9999       1263                2             4      2          9            1
#
# ...

# %%
reg = setup(data=df,target='interest_rate')
# Out:
# <style type="text/css">
# #T_1d67e_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1d67e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d67e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1d67e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d67e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d67e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1d67e_row0_col1" class="data row0 col1" >7096</td>
#     </tr>
#     <tr>
#       <th id="T_1d67e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d67e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1d67e_row1_col1" class="data row1 col1" >interest_rate</td>
#     </tr>
#     <tr>
#       <th id="T_1d67e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
reg1 = compare_models()
# Out:
# <style type="text/css">
# #T_107dc th {
#   text-align: left;
# }
# ...

# %%
df_perdi = predict_model(reg1, data = df)
df_perdi
# Out:
# <style type="text/css">
# </style>
# <table id="T_65a49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65a49_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_65a49_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_65a49_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_65a49_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_65a49_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_65a49_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_65a49_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65a49_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_65a49_row0_col1" class="data row0 col1" >0.0368</td>
# ...

# %% [markdown]
# 99% interest_rate có thể dự đoan bằng mô hình
# The MSE of interest_rate and predicted value is :  0.0205
# The MAE of interest_rate and predicted value is :  0.0368

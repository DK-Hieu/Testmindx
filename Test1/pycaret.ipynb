# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from io import StringIO
from sklearn.linear_model import LinearRegression
from pycaret.regression import *
print('Completed import lib')
# Out:
# Completed import lib

# %%
df = pd.read_csv('test1_pycaret.csv')
df.drop(columns='Unnamed: 0', inplace=True)
df
# Out:
#       emp_title  verified_income  loan_purpose  grade  sub_grade  loan_status  \
# 0          2928                1             1      3         13            1
# 1          4103                2             2      3         11            1
# 2           711                3             3      4         16            1
# 3          1449                2             2      1          3            1
# 4          4679                1             4      3         13            1
# ...         ...              ...           ...    ...        ...          ...
# 9995       1763                3             3      1          4            1
# 9996        419                1             2      4         18            1
# 9997       2271                1             2      5         22            1
# 9998       1173                3             3      1          1            1
# 9999        986                2             4      2          9            1
#
#       initial_listing_status  disbursement_method  annual_income  \
# 0                          1                    1        90000.0
# 1                          1                    1        40000.0
# 2                          2                    1        40000.0
# 3                          1                    1        30000.0
# 4                          1                    1        35000.0
# ...                      ...                  ...            ...
# 9995                       1                    1       108000.0
# 9996                       1                    1       121000.0
# 9997                       2                    1        67000.0
# 9998                       1                    1        80000.0
# 9999                       1                    1        66000.0
#
#       debt_to_income  ...  earliest_credit_line  inquiries_last_12m  \
# 0              18.01  ...                  2001                   6
# 1               5.04  ...                  1996                   1
# 2              21.15  ...                  2006                   4
# 3              10.16  ...                  2007                   0
# 4              57.96  ...                  2008                   7
# ...              ...  ...                   ...                 ...
# 9995           22.28  ...                  2008                   5
# 9996           32.38  ...                  1994                   1
# 9997           45.26  ...                  2004                   0
# 9998           11.99  ...                  1999                   1
# 9999           20.82  ...                  2005                   0
#
#       total_credit_limit  accounts_opened_24m  total_debit_limit  term  \
# 0                  70795                    5              11100    60
# 1                  28800                   11              16500    36
# 2                  24193                   13               4300    36
# 3                  25400                    1              19400    36
# 4                  69839                    6              32700    36
# ...                  ...                  ...                ...   ...
# 9995              199195                    8              44600    36
# 9996              382061                    0              28200    36
# 9997              346402                    4              14900    36
# 9998              294475                    2              46000    36
# 9999               91887                    4              36800    36
#
#       num_mort_accounts  account_never_delinq_percent  installment  \
# 0                     1                          92.9       652.53
# 1                     0                         100.0       167.54
# 2                     0                          93.5        71.40
# 3                     0                         100.0       664.19
# 4                     0                         100.0       786.87
# ...                 ...                           ...          ...
# 9995                  1                         100.0       744.90
# 9996                  2                          82.1       366.72
# 9997                  2                          72.2      1175.10
# 9998                  6                         100.0       722.76
# 9999                  0                         100.0       418.52
#
#       interest_rate
# 0             14.07
# 1             12.61
# 2             17.09
# 3              6.72
# 4             14.07
# ...             ...
# 9995           7.35
# 9996          19.03
# 9997          23.88
# 9998           5.32
# 9999          10.91
#
# [10000 rows x 22 columns]

# %%
reg = setup(data=df,target='interest_rate')
# Out:
# <style type="text/css">
# #T_75daf_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_75daf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75daf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_75daf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75daf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75daf_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_75daf_row0_col1" class="data row0 col1" >173</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75daf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_75daf_row1_col1" class="data row1 col1" >interest_rate</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75daf_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_75daf_row2_col1" class="data row2 col1" >(10000, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75daf_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_75daf_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75daf_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_75daf_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75daf_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_75daf_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_75daf_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_75daf_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_75daf_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_75daf_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_75daf_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_75daf_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_75daf_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_75daf_row9_col1" class="data row9 col1" >(6999, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_75daf_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_75daf_row10_col1" class="data row10 col1" >(3001, 58)</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_75daf_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_75daf_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_75daf_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_75daf_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_75daf_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_75daf_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_75daf_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_75daf_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_75daf_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_75daf_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_75daf_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_75daf_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_75daf_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_75daf_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_75daf_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_75daf_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_75daf_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_75daf_row19_col1" class="data row19 col1" >bf9b</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_75daf_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_75daf_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_75daf_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_75daf_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_75daf_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_75daf_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_75daf_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_75daf_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_75daf_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_75daf_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_75daf_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_75daf_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_75daf_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_75daf_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_75daf_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_75daf_row27_col1" class="data row27 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_75daf_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_75daf_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_75daf_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_75daf_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75daf_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_75daf_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_75daf_row30_col1" class="data row30 col1" >N

# %%
reg1 = compare_models()
# Out:
# <style type="text/css">
# </style>
# <table id="T_53133">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
df_perdi = predict_model(reg1, data = df)
df_perdi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\DATA MINDX\Mindx-Career-Kick-start\Test1\pycaret.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/f%3A/DATA%20MINDX/Mindx-Career-Kick-start/Test1/pycaret.ipynb#ch0000004?line=0'>1</a> df_perdi = predict_model(reg1, data = df)
#       <a href='vscode-notebook-cell:/f%3A/DATA%20MINDX/Mindx-Career-Kick-start/Test1/pycaret.ipynb#ch0000004?line=1'>2</a> df_perdi
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\regression.py:1759, in predict_model(estimator, data, drift_report, round, verbose)
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1698'>1699</a> def predict_model(
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1699'>1700</a>     estimator,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1700'>1701</a>     data: Optional[pd.DataFrame] = None,
#    (...)
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1703'>1704</a>     verbose: bool = True,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1704'>1705</a> ) -> pd.DataFrame:
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1706'>1707</a>     """
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1707'>1708</a>     This function predicts ``Label`` using a trained model. When ``data`` is
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1708'>1709</a>     None, it predicts label on the holdout set.
#    (...)
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1755'>1756</a>
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1756'>1757</a>     """
# -> <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1758'>1759</a>     return pycaret.internal.tabular.predict_model(
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1759'>1760</a>         estimator=estimator,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1760'>1761</a>         data=data,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1761'>1762</a>         drift_report=drift_report,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1762'>1763</a>         probability_threshold=None,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1763'>1764</a>         encoded_labels=True,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1764'>1765</a>         round=round,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1765'>1766</a>         verbose=verbose,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1766'>1767</a>         ml_usecase=MLUsecase.REGRESSION,
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/regression.py?line=1767'>1768</a>     )
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\internal\tabular.py:8815, in predict_model(estimator, data, probability_threshold, encoded_labels, drift_report, raw_score, round, verbose, ml_usecase, display)
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/internal/tabular.py?line=8811'>8812</a>         probability_threshold = estimator.probability_threshold
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/internal/tabular.py?line=8812'>8813</a>     estimator = get_estimator_from_meta_estimator(estimator)
# -> <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/internal/tabular.py?line=8814'>8815</a> pred = np.nan_to_num(estimator.predict(X_test_))
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/internal/tabular.py?line=8816'>8817</a> try:
#    <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/pycaret/internal/tabular.py?line=8817'>8818</a>     score = estimator.predict_proba(X_test_)
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\metaestimators.py:113, in _IffHasAttrDescriptor.__get__(self, obj, type)
#     <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/sklearn/utils/metaestimators.py?line=110'>111</a>         continue
#     <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/sklearn/utils/metaestimators.py?line=111'>112</a>     else:
# --> <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/sklearn/utils/metaestimators.py?line=112'>113</a>         getattr(delegate, self.attribute_name)
#     <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/sklearn/utils/metaestimators.py?line=113'>114</a>         break
#     <a href='file:///c%3A/Users/dk201/anaconda3/envs/pycaret/lib/site-packages/sklearn/utils/metaestimators.py?line=114'>115</a> else:
#
# AttributeError: 'list' object has no attribute 'predict'
